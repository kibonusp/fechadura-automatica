# %% [markdown]
# # Visão Computacional Entrega 2 - Fechadura Automática
# Alunos:
# - Gabriel Alves Kuabara - 11275043
# - Gabriel Freitas Ximenes de Vasconcelos - 11819084
# - Gabriel Victor Cardoso Fernandes - 11878296

# %%
import os
import pickle
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import pandas as pd
import cv2
import tensorflow.keras as keras
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.mobilenet import preprocess_input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# # Preprocessing the images used for training

# %%
def detect_face_and_save():
    folder_name = 'photos'

    # dimension of images
    image_width = 224
    image_height = 224

    # for detecting faces
    facecascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

    # set the directory containing the images
    images_dir = os.path.join(".", folder_name)

    current_id = 0
    label_ids = {}

    # iterates through all the files in each subdirectories
    for root, _, files in os.walk(images_dir):
        for file in files:
            if file.endswith("png") or file.endswith("jpg") or file.endswith("jpeg"):
                # path of the image
                path = os.path.join(root, file)

                # get the label name (name of the person)
                label = os.path.basename(root).replace(" ", ".").lower()

                # add the label (key) and its number (value)
                if not label in label_ids:
                    label_ids[label] = current_id
                    current_id += 1

                # load the image
                imgtest = cv2.imread(path, cv2.IMREAD_COLOR)
                image_array = np.array(imgtest, "uint8")
                # get the faces detected in the image
                faces = facecascade.detectMultiScale(imgtest, scaleFactor=1.1, minNeighbors=5)
                face_qty = len(faces)
                if face_qty == 0:
                    print(f"Face detector found 0 faces in file '{file}'")
                    os.remove(path)

                # save the detected face(s) and associate
                # them with the label
                for (x_, y_, w, h) in faces[:1]:

                    # resize the detected face to 224x224
                    size = (image_width, image_height)

                    # detected face region
                    roi = image_array[y_: y_ + h, x_: x_ + w]

                    # resize the detected head to target size
                    resized_image = cv2.resize(roi, size)
                    image_array = np.array(resized_image, "uint8")

                    # remove the original image
                    os.remove(path)

                    # replace the image with only the face
                    im = Image.fromarray(image_array)
                    im.save(path)

# %%
detect_face_and_save()
# Out:
# .\photos\Unknown
# File '1 (100).png' has 0 faces bro
# File '1 (1025).jpg' has 0 faces bro
# File '1 (1045).jpg' has 0 faces bro
# File '1 (1056).jpg' has 0 faces bro
# File '1 (106).jpg' has 0 faces bro
# File '1 (1072).jpg' has 0 faces bro
# File '1 (1081).jpg' has 0 faces bro
# File '1 (109).jpg' has 0 faces bro
# File '1 (1094).jpg' has 0 faces bro
# File '1 (1103).jpg' has 0 faces bro
# File '1 (1112).jpg' has 0 faces bro
# File '1 (1117).jpg' has 0 faces bro
# File '1 (1118).jpg' has 0 faces bro
# File '1 (1122).jpg' has 0 faces bro
# File '1 (113).jpg' has 0 faces bro
# File '1 (1148).jpg' has 0 faces bro
# File '1 (116).jpg' has 0 faces bro
# File '1 (1168).jpg' has 0 faces bro
# File '1 (1184).jpg' has 0 faces bro
# File '1 (1192).jpg' has 0 faces bro
# File '1 (1193).jpg' has 0 faces bro
# File '1 (1225).jpg' has 0 faces bro
# File '1 (1229).jpg' has 0 faces bro
# File '1 (1231).jpg' has 0 faces bro
# File '1 (1242).jpg' has 0 faces bro
# File '1 (1245).jpg' has 0 faces bro
# File '1 (125).jpg' has 0 faces bro
# File '1 (125).png' has 0 faces bro
# File '1 (1252).jpg' has 0 faces bro
# File '1 (1259).jpg' has 0 faces bro
# File '1 (1263).jpg' has 0 faces bro
# File '1 (1282).jpg' has 0 faces bro
# File '1 (1287).jpg' has 0 faces bro
# File '1 (1293).jpg' has 0 faces bro
# File '1 (1294).jpg' has 0 faces bro
# File '1 (1301).jpg' has 0 faces bro
# File '1 (1303).jpg' has 0 faces bro
# File '1 (1304).jpg' has 0 faces bro
# File '1 (1306).jpg' has 0 faces bro
# File '1 (1307).jpg' has 0 faces bro
# File '1 (1325).jpg' has 0 faces bro
# File '1 (1328).jpg' has 0 faces bro
# File '1 (1331).jpg' has 0 faces bro
# File '1 (1353).jpg' has 0 faces bro
# File '1 (1368).jpg' has 0 faces bro
# File '1 (137).jpg' has 0 faces bro
# File '1 (139).jpg' has 0 faces bro
# File '1 (1391).jpg' has 0 faces bro
# File '1 (1392).jpg' has 0 faces bro
# File '1 (1397).jpg' has 0 faces bro
# File '1 (14).png' has 0 faces bro
# File '1 (140).png' has 0 faces bro
# File '1 (1409).jpg' has 0 faces bro
# File '1 (141).jpg' has 0 faces bro
# File '1 (1417).jpg' has 0 faces bro
# File '1 (1419).jpg' has 0 faces bro
# File '1 (142).jpg' has 0 faces bro
# File '1 (1421).jpg' has 0 faces bro
# File '1 (1423).jpg' has 0 faces bro
# File '1 (1426).jpg' has 0 faces bro
# File '1 (1430).jpg' has 0 faces bro
# File '1 (144).png' has 0 faces bro
# File '1 (1447).jpg' has 0 faces bro
# File '1 (1448).jpg' has 0 faces bro
# File '1 (1459).jpg' has 0 faces bro
# File '1 (1462).jpg' has 0 faces bro
# File '1 (1467).jpg' has 0 faces bro
# File '1 (1474).jpg' has 0 faces bro
# File '1 (1481).jpg' has 0 faces bro
# File '1 (1483).jpg' has 0 faces bro
# File '1 (1499).jpg' has 0 faces bro
# File '1 (1506).jpg' has 0 faces bro
# File '1 (1507).jpg' has 0 faces bro
# File '1 (1513).jpg' has 0 faces bro
# File '1 (1517).jpg' has 0 faces bro
# File '1 (1524).jpg' has 0 faces bro
# File '1 (1530).jpg' has 0 faces bro
# File '1 (1533).jpg' has 0 faces bro
# File '1 (1535).jpg' has 0 faces bro
# File '1 (1542).jpg' has 0 faces bro
# File '1 (155).jpg' has 0 faces bro
# File '1 (1563).jpg' has 0 faces bro
# File '1 (1572).jpg' has 0 faces bro
# File '1 (1586).jpg' has 0 faces bro
# File '1 (1591).jpg' has 0 faces bro
# File '1 (161).jpg' has 0 faces bro
# File '1 (1625).jpg' has 0 faces bro
# File '1 (1639).jpg' has 0 faces bro
# File '1 (1663).jpg' has 0 faces bro
# File '1 (1666).jpg' has 0 faces bro
# File '1 (1669).jpg' has 0 faces bro
# File '1 (167).jpg' has 0 faces bro
# File '1 (1676).jpg' has 0 faces bro
# File '1 (1679).jpg' has 0 faces bro
# File '1 (1686).jpg' has 0 faces bro
# File '1 (1696).jpg' has 0 faces bro
# File '1 (1702).jpg' has 0 faces bro
# File '1 (1710).jpg' has 0 faces bro
# File '1 (1712).jpg' has 0 faces bro
# File '1 (1724).jpg' has 0 faces bro
# File '1 (1725).jpg' has 0 faces bro
# File '1 (1727).jpg' has 0 faces bro
# File '1 (1742).jpg' has 0 faces bro
# File '1 (1748).jpg' has 0 faces bro
# File '1 (1752).jpg' has 0 faces bro
# File '1 (1755).jpg' has 0 faces bro
# File '1 (1757).jpg' has 0 faces bro
# File '1 (1758).jpg' has 0 faces bro
# File '1 (1759).jpg' has 0 faces bro
# File '1 (1766).jpg' has 0 faces bro
# File '1 (1769).jpg' has 0 faces bro
# File '1 (1770).jpg' has 0 faces bro
# File '1 (1771).jpg' has 0 faces bro
# File '1 (1795).jpg' has 0 faces bro
# File '1 (1801).jpg' has 0 faces bro
# File '1 (1807).jpg' has 0 faces bro
# File '1 (1812).jpg' has 0 faces bro
# File '1 (1833).jpg' has 0 faces bro
# File '1 (1838).jpg' has 0 faces bro
# File '1 (1847).jpg' has 0 faces bro
# File '1 (1855).jpg' has 0 faces bro
# File '1 (1857).jpg' has 0 faces bro
# File '1 (1860).jpg' has 0 faces bro
# File '1 (1864).jpg' has 0 faces bro
# File '1 (1869).jpg' has 0 faces bro
# File '1 (1881).jpg' has 0 faces bro
# File '1 (1916).jpg' has 0 faces bro
# File '1 (1926).jpg' has 0 faces bro
# File '1 (1928).jpg' has 0 faces bro
# File '1 (1934).jpg' has 0 faces bro
# File '1 (1939).jpg' has 0 faces bro
# File '1 (1948).jpg' has 0 faces bro
# File '1 (1949).jpg' has 0 faces bro
# File '1 (1955).jpg' has 0 faces bro
# File '1 (1956).jpg' has 0 faces bro
# File '1 (196).jpg' has 0 faces bro
# File '1 (1964).jpg' has 0 faces bro
# File '1 (1975).jpg' has 0 faces bro
# File '1 (1976).jpg' has 0 faces bro
# File '1 (1981).jpg' has 0 faces bro
# File '1 (1985).jpg' has 0 faces bro
# File '1 (1990).jpg' has 0 faces bro
# File '1 (1997).jpg' has 0 faces bro
# File '1 (2005).jpg' has 0 faces bro
# File '1 (201).jpg' has 0 faces bro
# File '1 (2013).jpg' has 0 faces bro
# File '1 (2025).jpg' has 0 faces bro
# File '1 (2026).jpg' has 0 faces bro
# File '1 (2027).jpg' has 0 faces bro
# File '1 (2031).jpg' has 0 faces bro
# File '1 (2033).jpg' has 0 faces bro
# File '1 (2047).jpg' has 0 faces bro
# File '1 (2048).jpg' has 0 faces bro
# File '1 (2055).jpg' has 0 faces bro
# File '1 (2056).jpg' has 0 faces bro
# File '1 (2062).jpg' has 0 faces bro
# File '1 (2068).jpg' has 0 faces bro
# File '1 (2074).jpg' has 0 faces bro
# File '1 (2079).jpg' has 0 faces bro
# File '1 (2085).jpg' has 0 faces bro
# File '1 (2091).jpg' has 0 faces bro
# File '1 (2093).jpg' has 0 faces bro
# File '1 (2095).jpg' has 0 faces bro
# File '1 (212).jpg' has 0 faces bro
# File '1 (2120).jpg' has 0 faces bro
# File '1 (2122).jpg' has 0 faces bro
# File '1 (2126).jpg' has 0 faces bro
# File '1 (2128).jpg' has 0 faces bro
# File '1 (2139).jpg' has 0 faces bro
# File '1 (2140).jpg' has 0 faces bro
# File '1 (2141).jpg' has 0 faces bro
# File '1 (2143).jpg' has 0 faces bro
# File '1 (2159).jpg' has 0 faces bro
# File '1 (2164).jpg' has 0 faces bro
# File '1 (2175).jpg' has 0 faces bro
# File '1 (2195).jpg' has 0 faces bro
# File '1 (2201).jpg' has 0 faces bro
# File '1 (2205).jpg' has 0 faces bro
# File '1 (2209).jpg' has 0 faces bro
# File '1 (2215).jpg' has 0 faces bro
# File '1 (2220).jpg' has 0 faces bro
# File '1 (2229).jpg' has 0 faces bro
# File '1 (2246).jpg' has 0 faces bro
# File '1 (2249).jpg' has 0 faces bro
# File '1 (2255).jpg' has 0 faces bro
# File '1 (2260).jpg' has 0 faces bro
# File '1 (2265).jpg' has 0 faces bro
# File '1 (2267).jpg' has 0 faces bro
# File '1 (2281).jpg' has 0 faces bro
# File '1 (2304).jpg' has 0 faces bro
# File '1 (2306).jpg' has 0 faces bro
# File '1 (2311).jpg' has 0 faces bro
# File '1 (2319).jpg' has 0 faces bro
# File '1 (2326).jpg' has 0 faces bro
# File '1 (2345).jpg' has 0 faces bro
# File '1 (2353).jpg' has 0 faces bro
# File '1 (2358).jpg' has 0 faces bro
# File '1 (2369).jpg' has 0 faces bro
# File '1 (237).jpg' has 0 faces bro
# File '1 (2373).jpg' has 0 faces bro
# File '1 (2376).jpg' has 0 faces bro
# File '1 (2379).jpg' has 0 faces bro
# File '1 (2387).jpg' has 0 faces bro
# File '1 (2391).jpg' has 0 faces bro
# File '1 (2393).jpg' has 0 faces bro
# File '1 (2394).jpg' has 0 faces bro
# File '1 (2396).jpg' has 0 faces bro
# File '1 (2397).jpg' has 0 faces bro
# File '1 (2401).jpg' has 0 faces bro
# File '1 (2405).jpg' has 0 faces bro
# File '1 (2409).jpg' has 0 faces bro
# File '1 (2416).jpg' has 0 faces bro
# File '1 (242).jpg' has 0 faces bro
# File '1 (2427).jpg' has 0 faces bro
# File '1 (2429).jpg' has 0 faces bro
# File '1 (2430).jpg' has 0 faces bro
# File '1 (245).jpg' has 0 faces bro
# File '1 (2471).jpg' has 0 faces bro
# File '1 (2479).jpg' has 0 faces bro
# File '1 (2487).jpg' has 0 faces bro
# File '1 (2488).jpg' has 0 faces bro
# File '1 (2490).jpg' has 0 faces bro
# File '1 (2493).jpg' has 0 faces bro
# File '1 (2494).jpg' has 0 faces bro
# File '1 (2498).jpg' has 0 faces bro
# File '1 (250).jpg' has 0 faces bro
# File '1 (2512).jpg' has 0 faces bro
# File '1 (2515).jpg' has 0 faces bro
# File '1 (2517).jpg' has 0 faces bro
# File '1 (2518).jpg' has 0 faces bro
# File '1 (2527).jpg' has 0 faces bro
# File '1 (2528).jpg' has 0 faces bro
# File '1 (2534).jpg' has 0 faces bro
# File '1 (2545).jpg' has 0 faces bro
# File '1 (2549).jpg' has 0 faces bro
# File '1 (2554).jpg' has 0 faces bro
# File '1 (2558).jpg' has 0 faces bro
# File '1 (2560).jpg' has 0 faces bro
# File '1 (2566).jpg' has 0 faces bro
# File '1 (2568).jpg' has 0 faces bro
# File '1 (257).jpg' has 0 faces bro
# File '1 (2573).jpg' has 0 faces bro
# File '1 (2577).jpg' has 0 faces bro
# File '1 (258).jpg' has 0 faces bro
# File '1 (2599).jpg' has 0 faces bro
# File '1 (26).jpeg' has 0 faces bro
# File '1 (2602).jpg' has 0 faces bro
# File '1 (2603).jpg' has 0 faces bro
# File '1 (2606).jpg' has 0 faces bro
# File '1 (2607).jpg' has 0 faces bro
# File '1 (2621).jpg' has 0 faces bro
# File '1 (2625).jpg' has 0 faces bro
# File '1 (2629).jpg' has 0 faces bro
# File '1 (2634).jpg' has 0 faces bro
# File '1 (2635).jpg' has 0 faces bro
# File '1 (2637).jpg' has 0 faces bro
# File '1 (2639).jpg' has 0 faces bro
# File '1 (2641).jpg' has 0 faces bro
# File '1 (2649).jpg' has 0 faces bro
# File '1 (2650).jpg' has 0 faces bro
# File '1 (2651).jpg' has 0 faces bro
# File '1 (2653).jpg' has 0 faces bro
# File '1 (2658).jpg' has 0 faces bro
# File '1 (2663).jpg' has 0 faces bro
# File '1 (2666).jpg' has 0 faces bro
# File '1 (2671).jpg' has 0 faces bro
# File '1 (2685).jpg' has 0 faces bro
# File '1 (2686).jpg' has 0 faces bro
# File '1 (2693).jpg' has 0 faces bro
# File '1 (2698).jpg' has 0 faces bro
# File '1 (2700).jpg' has 0 faces bro
# File '1 (2710).jpg' has 0 faces bro
# File '1 (2726).jpg' has 0 faces bro
# File '1 (2731).jpg' has 0 faces bro
# File '1 (275).jpg' has 0 faces bro
# File '1 (2752).jpg' has 0 faces bro
# File '1 (278).jpg' has 0 faces bro
# File '1 (2781).jpg' has 0 faces bro
# File '1 (28).jpeg' has 0 faces bro
# File '1 (2802).jpg' has 0 faces bro
# File '1 (2810).jpg' has 0 faces bro
# File '1 (2813).jpg' has 0 faces bro
# File '1 (2816).jpg' has 0 faces bro
# File '1 (2818).jpg' has 0 faces bro
# File '1 (2827).jpg' has 0 faces bro
# File '1 (2836).jpg' has 0 faces bro
# File '1 (2838).jpg' has 0 faces bro
# File '1 (284).jpg' has 0 faces bro
# File '1 (2844).jpg' has 0 faces bro
# File '1 (285).jpg' has 0 faces bro
# File '1 (2850).jpg' has 0 faces bro
# File '1 (2853).jpg' has 0 faces bro
# File '1 (2868).jpg' has 0 faces bro
# File '1 (2879).jpg' has 0 faces bro
# File '1 (288).jpg' has 0 faces bro
# File '1 (2916).jpg' has 0 faces bro
# File '1 (2940).jpg' has 0 faces bro
# File '1 (2947).jpg' has 0 faces bro
# File '1 (2953).jpg' has 0 faces bro
# File '1 (2956).jpg' has 0 faces bro
# File '1 (2962).jpg' has 0 faces bro
# File '1 (297).jpg' has 0 faces bro
# File '1 (2971).jpg' has 0 faces bro
# File '1 (2989).jpg' has 0 faces bro
# File '1 (2995).jpg' has 0 faces bro
# File '1 (300).jpg' has 0 faces bro
# File '1 (3006).jpg' has 0 faces bro
# File '1 (3007).jpg' has 0 faces bro
# File '1 (3009).jpg' has 0 faces bro
# File '1 (3024).jpg' has 0 faces bro
# File '1 (3027).jpg' has 0 faces bro
# File '1 (3029).jpg' has 0 faces bro
# File '1 (3045).jpg' has 0 faces bro
# File '1 (305).jpg' has 0 faces bro
# File '1 (3069).jpg' has 0 faces bro
# File '1 (309).jpg' has 0 faces bro
# File '1 (3091).jpg' has 0 faces bro
# File '1 (3092).jpg' has 0 faces bro
# File '1 (3097).jpg' has 0 faces bro
# File '1 (3116).jpg' has 0 faces bro
# File '1 (3163).jpg' has 0 faces bro
# File '1 (3174).jpg' has 0 faces bro
# File '1 (319).jpg' has 0 faces bro
# File '1 (3203).jpg' has 0 faces bro
# File '1 (3223).jpg' has 0 faces bro
# File '1 (3234).jpg' has 0 faces bro
# File '1 (3242).jpg' has 0 faces bro
# File '1 (3243).jpg' has 0 faces bro
# File '1 (3259).jpg' has 0 faces bro
# File '1 (326).jpg' has 0 faces bro
# File '1 (3268).jpg' has 0 faces bro
# File '1 (3274).jpg' has 0 faces bro
# File '1 (33).png' has 0 faces bro
# File '1 (3308).jpg' has 0 faces bro
# File '1 (3320).jpg' has 0 faces bro
# File '1 (3343).jpg' has 0 faces bro
# File '1 (3358).jpg' has 0 faces bro
# File '1 (3367).jpg' has 0 faces bro
# File '1 (3373).jpg' has 0 faces bro
# File '1 (3382).jpg' has 0 faces bro
# File '1 (3386).jpg' has 0 faces bro
# File '1 (3395).jpg' has 0 faces bro
# File '1 (3427).jpg' has 0 faces bro
# File '1 (3453).jpg' has 0 faces bro
# File '1 (3478).jpg' has 0 faces bro
# File '1 (3496).jpg' has 0 faces bro
# File '1 (3498).jpg' has 0 faces bro
# File '1 (3502).jpg' has 0 faces bro
# File '1 (3513).jpg' has 0 faces bro
# File '1 (3515).jpg' has 0 faces bro
# File '1 (3526).jpg' has 0 faces bro
# File '1 (3528).jpg' has 0 faces bro
# File '1 (353).jpg' has 0 faces bro
# File '1 (3541).jpg' has 0 faces bro
# File '1 (3560).jpg' has 0 faces bro
# File '1 (3572).jpg' has 0 faces bro
# File '1 (3579).jpg' has 0 faces bro
# File '1 (3587).jpg' has 0 faces bro
# File '1 (3597).jpg' has 0 faces bro
# File '1 (3604).jpg' has 0 faces bro
# File '1 (3618).jpg' has 0 faces bro
# File '1 (3621).jpg' has 0 faces bro
# File '1 (364).jpg' has 0 faces bro
# File '1 (3648).jpg' has 0 faces bro
# File '1 (3649).jpg' has 0 faces bro
# File '1 (3652).jpg' has 0 faces bro
# File '1 (3655).jpg' has 0 faces bro
# File '1 (3670).jpg' has 0 faces bro
# File '1 (3672).jpg' has 0 faces bro
# File '1 (3677).jpg' has 0 faces bro
# File '1 (3679).jpg' has 0 faces bro
# File '1 (3684).jpg' has 0 faces bro
# File '1 (3690).jpg' has 0 faces bro
# File '1 (3692).jpg' has 0 faces bro
# File '1 (3695).jpg' has 0 faces bro
# File '1 (37).jpg' has 0 faces bro
# File '1 (3705).jpg' has 0 faces bro
# File '1 (3706).jpg' has 0 faces bro
# File '1 (3722).jpg' has 0 faces bro
# File '1 (3726).jpg' has 0 faces bro
# File '1 (3727).jpg' has 0 faces bro
# File '1 (373).jpg' has 0 faces bro
# File '1 (3767).jpg' has 0 faces bro
# File '1 (377).jpg' has 0 faces bro
# File '1 (3771).jpg' has 0 faces bro
# File '1 (3793).jpg' has 0 faces bro
# File '1 (3797).jpg' has 0 faces bro
# File '1 (380).jpg' has 0 faces bro
# File '1 (3809).jpg' has 0 faces bro
# File '1 (3829).jpg' has 0 faces bro
# File '1 (3835).jpg' has 0 faces bro
# File '1 (3839).jpg' has 0 faces bro
# File '1 (3843).jpg' has 0 faces bro
# File '1 (3859).jpg' has 0 faces bro
# File '1 (387).jpg' has 0 faces bro
# File '1 (3885).jpg' has 0 faces bro
# File '1 (389).jpg' has 0 faces bro
# File '1 (3892).jpg' has 0 faces bro
# File '1 (3901).jpg' has 0 faces bro
# File '1 (3908).jpg' has 0 faces bro
# File '1 (3917).jpg' has 0 faces bro
# File '1 (3922).jpg' has 0 faces bro
# File '1 (3926).jpg' has 0 faces bro
# File '1 (3956).jpg' has 0 faces bro
# File '1 (3968).jpg' has 0 faces bro
# File '1 (3972).jpg' has 0 faces bro
# File '1 (399).jpg' has 0 faces bro
# File '1 (3990).jpg' has 0 faces bro
# File '1 (3995).jpg' has 0 faces bro
# File '1 (40).jpeg' has 0 faces bro
# File '1 (400).jpg' has 0 faces bro
# File '1 (4028).jpg' has 0 faces bro
# File '1 (404).jpg' has 0 faces bro
# File '1 (4041).jpg' has 0 faces bro
# File '1 (4083).jpg' has 0 faces bro
# File '1 (4094).jpg' has 0 faces bro
# File '1 (4121).jpg' has 0 faces bro
# File '1 (4125).jpg' has 0 faces bro
# File '1 (413).jpg' has 0 faces bro
# File '1 (4140).jpg' has 0 faces bro
# File '1 (4158).jpg' has 0 faces bro
# File '1 (4165).jpg' has 0 faces bro
# File '1 (4169).jpg' has 0 faces bro
# File '1 (4183).jpg' has 0 faces bro
# File '1 (4184).jpg' has 0 faces bro
# File '1 (420).jpg' has 0 faces bro
# File '1 (4212).jpg' has 0 faces bro
# File '1 (4219).jpg' has 0 faces bro
# File '1 (4265).jpg' has 0 faces bro
# File '1 (4269).jpg' has 0 faces bro
# File '1 (427).jpg' has 0 faces bro
# File '1 (428).jpg' has 0 faces bro
# File '1 (4285).jpg' has 0 faces bro
# File '1 (429).jpg' has 0 faces bro
# File '1 (4300).jpg' has 0 faces bro
# File '1 (4304).jpg' has 0 faces bro
# File '1 (4315).jpg' has 0 faces bro
# File '1 (4330).jpg' has 0 faces bro
# File '1 (4334).jpg' has 0 faces bro
# File '1 (4340).jpg' has 0 faces bro
# File '1 (4360).jpg' has 0 faces bro
# File '1 (4363).jpg' has 0 faces bro
# File '1 (4379).jpg' has 0 faces bro
# File '1 (4388).jpg' has 0 faces bro
# File '1 (440).jpg' has 0 faces bro
# File '1 (4403).jpg' has 0 faces bro
# File '1 (4405).jpg' has 0 faces bro
# File '1 (4409).jpg' has 0 faces bro
# File '1 (4412).jpg' has 0 faces bro
# File '1 (4424).jpg' has 0 faces bro
# File '1 (4459).jpg' has 0 faces bro
# File '1 (4467).jpg' has 0 faces bro
# File '1 (4478).jpg' has 0 faces bro
# File '1 (4486).jpg' has 0 faces bro
# File '1 (4494).jpg' has 0 faces bro
# File '1 (4497).jpg' has 0 faces bro
# File '1 (4498).jpg' has 0 faces bro
# File '1 (450).jpg' has 0 faces bro
# File '1 (4508).jpg' has 0 faces bro
# File '1 (4522).jpg' has 0 faces bro
# File '1 (4533).jpg' has 0 faces bro
# File '1 (4565).jpg' has 0 faces bro
# File '1 (457).jpg' has 0 faces bro
# File '1 (4572).jpg' has 0 faces bro
# File '1 (4574).jpg' has 0 faces bro
# File '1 (4590).jpg' has 0 faces bro
# File '1 (4592).jpg' has 0 faces bro
# File '1 (4598).jpg' has 0 faces bro
# File '1 (46).jpeg' has 0 faces bro
# File '1 (462).jpg' has 0 faces bro
# File '1 (463).jpg' has 0 faces bro
# File '1 (464).jpg' has 0 faces bro
# File '1 (4643).jpg' has 0 faces bro
# File '1 (4644).jpg' has 0 faces bro
# File '1 (4664).jpg' has 0 faces bro
# File '1 (4672).jpg' has 0 faces bro
# File '1 (4681).jpg' has 0 faces bro
# File '1 (4693).jpg' has 0 faces bro
# File '1 (4709).jpg' has 0 faces bro
# File '1 (4718).jpg' has 0 faces bro
# File '1 (4727).jpg' has 0 faces bro
# File '1 (474).jpg' has 0 faces bro
# File '1 (4743).jpg' has 0 faces bro
# File '1 (4764).jpg' has 0 faces bro
# File '1 (48).jpg' has 0 faces bro
# File '1 (480).jpg' has 0 faces bro
# File '1 (4805).jpg' has 0 faces bro
# File '1 (4812).jpg' has 0 faces bro
# File '1 (4816).jpg' has 0 faces bro
# File '1 (4827).jpg' has 0 faces bro
# File '1 (485).jpg' has 0 faces bro
# File '1 (4851).jpg' has 0 faces bro
# File '1 (486).jpg' has 0 faces bro
# File '1 (4862).jpg' has 0 faces bro
# File '1 (4867).jpg' has 0 faces bro
# File '1 (487).jpg' has 0 faces bro
# File '1 (4871).jpg' has 0 faces bro
# File '1 (4873).jpg' has 0 faces bro
# File '1 (4889).jpg' has 0 faces bro
# File '1 (4898).jpg' has 0 faces bro
# File '1 (4930).jpg' has 0 faces bro
# File '1 (494).jpg' has 0 faces bro
# File '1 (4941).jpg' has 0 faces bro
# File '1 (4953).jpg' has 0 faces bro
# File '1 (4955).jpg' has 0 faces bro
# File '1 (4963).jpg' has 0 faces bro
# File '1 (4979).jpg' has 0 faces bro
# File '1 (4986).jpg' has 0 faces bro
# File '1 (4989).jpg' has 0 faces bro
# File '1 (499).jpg' has 0 faces bro
# File '1 (5011).jpg' has 0 faces bro
# File '1 (5036).jpg' has 0 faces bro
# File '1 (5042).jpg' has 0 faces bro
# File '1 (5087).jpg' has 0 faces bro
# File '1 (509).jpg' has 0 faces bro
# File '1 (510).jpg' has 0 faces bro
# File '1 (5100).jpg' has 0 faces bro
# File '1 (5114).jpg' has 0 faces bro
# File '1 (5123).jpg' has 0 faces bro
# File '1 (5124).jpg' has 0 faces bro
# File '1 (5140).jpg' has 0 faces bro
# File '1 (5156).jpg' has 0 faces bro
# File '1 (5168).jpg' has 0 faces bro
# File '1 (5177).jpg' has 0 faces bro
# File '1 (5181).jpg' has 0 faces bro
# File '1 (52).png' has 0 faces bro
# File '1 (520).jpg' has 0 faces bro
# File '1 (5200).jpg' has 0 faces bro
# File '1 (5202).jpg' has 0 faces bro
# File '1 (5244).jpg' has 0 faces bro
# File '1 (5252).jpg' has 0 faces bro
# File '1 (5277).jpg' has 0 faces bro
# File '1 (5281).jpg' has 0 faces bro
# File '1 (529).jpg' has 0 faces bro
# File '1 (53).jpg' has 0 faces bro
# File '1 (5300).jpg' has 0 faces bro
# File '1 (5318).jpg' has 0 faces bro
# File '1 (5319).jpg' has 0 faces bro
# File '1 (532).jpg' has 0 faces bro
# File '1 (5324).jpg' has 0 faces bro
# File '1 (5335).jpg' has 0 faces bro
# File '1 (534).jpg' has 0 faces bro
# File '1 (5350).jpg' has 0 faces bro
# File '1 (5351).jpg' has 0 faces bro
# File '1 (5355).jpg' has 0 faces bro
# File '1 (536).jpg' has 0 faces bro
# File '1 (5387).jpg' has 0 faces bro
# File '1 (54).jpeg' has 0 faces bro
# File '1 (5402).jpg' has 0 faces bro
# File '1 (541).jpg' has 0 faces bro
# File '1 (5417).jpg' has 0 faces bro
# File '1 (5421).jpg' has 0 faces bro
# File '1 (5428).jpg' has 0 faces bro
# File '1 (5432).jpg' has 0 faces bro
# File '1 (5434).jpg' has 0 faces bro
# File '1 (5448).jpg' has 0 faces bro
# File '1 (545).jpg' has 0 faces bro
# File '1 (5461).jpg' has 0 faces bro
# File '1 (5471).jpg' has 0 faces bro
# File '1 (5472).jpg' has 0 faces bro
# File '1 (5477).jpg' has 0 faces bro
# File '1 (549).jpg' has 0 faces bro
# File '1 (55).jpg' has 0 faces bro
# File '1 (5502).jpg' has 0 faces bro
# File '1 (5503).jpg' has 0 faces bro
# File '1 (5522).jpg' has 0 faces bro
# File '1 (5529).jpg' has 0 faces bro
# File '1 (554).jpg' has 0 faces bro
# File '1 (5543).jpg' has 0 faces bro
# File '1 (5561).jpg' has 0 faces bro
# File '1 (5586).jpg' has 0 faces bro
# File '1 (5627).jpg' has 0 faces bro
# File '1 (563).jpg' has 0 faces bro
# File '1 (564).jpg' has 0 faces bro
# File '1 (5649).jpg' has 0 faces bro
# File '1 (5651).jpg' has 0 faces bro
# File '1 (5676).jpg' has 0 faces bro
# File '1 (5693).jpg' has 0 faces bro
# File '1 (5731).jpg' has 0 faces bro
# File '1 (5733).jpg' has 0 faces bro
# File '1 (5758).jpg' has 0 faces bro
# File '1 (576).jpg' has 0 faces bro
# File '1 (5769).jpg' has 0 faces bro
# File '1 (5773).jpg' has 0 faces bro
# File '1 (5778).jpg' has 0 faces bro
# File '1 (5798).jpg' has 0 faces bro
# File '1 (58).png' has 0 faces bro
# File '1 (5804).jpg' has 0 faces bro
# File '1 (5814).jpg' has 0 faces bro
# File '1 (5820).jpg' has 0 faces bro
# File '1 (5838).jpg' has 0 faces bro
# File '1 (585).jpg' has 0 faces bro
# File '1 (5862).jpg' has 0 faces bro
# File '1 (5864).jpg' has 0 faces bro
# File '1 (5872).jpg' has 0 faces bro
# File '1 (5875).jpg' has 0 faces bro
# File '1 (5884).jpg' has 0 faces bro
# File '1 (5893).jpg' has 0 faces bro
# File '1 (59).jpeg' has 0 faces bro
# File '1 (5915).jpg' has 0 faces bro
# File '1 (5917).jpg' has 0 faces bro
# File '1 (5919).jpg' has 0 faces bro
# File '1 (592).jpg' has 0 faces bro
# File '1 (5923).jpg' has 0 faces bro
# File '1 (5926).jpg' has 0 faces bro
# File '1 (5928).jpg' has 0 faces bro
# File '1 (5930).jpg' has 0 faces bro
# File '1 (5931).jpg' has 0 faces bro
# File '1 (5939).jpg' has 0 faces bro
# File '1 (5944).jpg' has 0 faces bro
# File '1 (5949).jpg' has 0 faces bro
# File '1 (5952).jpg' has 0 faces bro
# File '1 (5966).jpg' has 0 faces bro
# File '1 (5967).jpg' has 0 faces bro
# File '1 (5974).jpg' has 0 faces bro
# File '1 (5976).jpg' has 0 faces bro
# File '1 (5980).jpg' has 0 faces bro
# File '1 (5982).jpg' has 0 faces bro
# File '1 (5987).jpg' has 0 faces bro
# File '1 (5991).jpg' has 0 faces bro
# File '1 (5996).jpg' has 0 faces bro
# File '1 (6001).jpg' has 0 faces bro
# File '1 (6007).jpg' has 0 faces bro
# File '1 (6008).jpg' has 0 faces bro
# File '1 (6009).jpg' has 0 faces bro
# File '1 (6015).jpg' has 0 faces bro
# File '1 (6028).jpg' has 0 faces bro
# File '1 (6056).jpg' has 0 faces bro
# File '1 (6057).jpg' has 0 faces bro
# File '1 (6058).jpg' has 0 faces bro
# File '1 (606).jpg' has 0 faces bro
# File '1 (6065).jpg' has 0 faces bro
# File '1 (6072).jpg' has 0 faces bro
# File '1 (61).jpg' has 0 faces bro
# File '1 (6103).jpg' has 0 faces bro
# File '1 (6108).jpg' has 0 faces bro
# File '1 (6109).jpg' has 0 faces bro
# File '1 (6112).jpg' has 0 faces bro
# File '1 (6125).jpg' has 0 faces bro
# File '1 (6127).jpg' has 0 faces bro
# File '1 (613).jpg' has 0 faces bro
# File '1 (6133).jpg' has 0 faces bro
# File '1 (6134).jpg' has 0 faces bro
# File '1 (6138).jpg' has 0 faces bro
# File '1 (615).jpg' has 0 faces bro
# File '1 (6150).jpg' has 0 faces bro
# File '1 (6157).jpg' has 0 faces bro
# File '1 (6160).jpg' has 0 faces bro
# File '1 (6169).jpg' has 0 faces bro
# File '1 (617).jpg' has 0 faces bro
# File '1 (6179).jpg' has 0 faces bro
# File '1 (618).jpg' has 0 faces bro
# File '1 (6185).jpg' has 0 faces bro
# File '1 (619).jpg' has 0 faces bro
# File '1 (6190).jpg' has 0 faces bro
# File '1 (6192).jpg' has 0 faces bro
# File '1 (6198).jpg' has 0 faces bro
# File '1 (62).jpeg' has 0 faces bro
# File '1 (6219).jpg' has 0 faces bro
# File '1 (6226).jpg' has 0 faces bro
# File '1 (6228).jpg' has 0 faces bro
# File '1 (6229).jpg' has 0 faces bro
# File '1 (623).jpg' has 0 faces bro
# File '1 (6230).jpg' has 0 faces bro
# File '1 (6233).jpg' has 0 faces bro
# File '1 (6236).jpg' has 0 faces bro
# File '1 (6237).jpg' has 0 faces bro
# File '1 (6245).jpg' has 0 faces bro
# File '1 (6248).jpg' has 0 faces bro
# File '1 (6249).jpg' has 0 faces bro
# File '1 (6251).jpg' has 0 faces bro
# File '1 (6252).jpg' has 0 faces bro
# File '1 (6257).jpg' has 0 faces bro
# File '1 (6260).jpg' has 0 faces bro
# File '1 (6274).jpg' has 0 faces bro
# File '1 (6276).jpg' has 0 faces bro
# File '1 (6279).jpg' has 0 faces bro
# File '1 (6284).jpg' has 0 faces bro
# File '1 (6285).jpg' has 0 faces bro
# File '1 (6294).jpg' has 0 faces bro
# File '1 (6299).jpg' has 0 faces bro
# File '1 (63).jpg' has 0 faces bro
# File '1 (6312).jpg' has 0 faces bro
# File '1 (6336).jpg' has 0 faces bro
# File '1 (6338).jpg' has 0 faces bro
# File '1 (6343).jpg' has 0 faces bro
# File '1 (6345).jpg' has 0 faces bro
# File '1 (6353).jpg' has 0 faces bro
# File '1 (6373).jpg' has 0 faces bro
# File '1 (6376).jpg' has 0 faces bro
# File '1 (6381).jpg' has 0 faces bro
# File '1 (6394).jpg' has 0 faces bro
# File '1 (6396).jpg' has 0 faces bro
# File '1 (6398).jpg' has 0 faces bro
# File '1 (6403).jpg' has 0 faces bro
# File '1 (641).jpg' has 0 faces bro
# File '1 (6420).jpg' has 0 faces bro
# File '1 (6421).jpg' has 0 faces bro
# File '1 (6424).jpg' has 0 faces bro
# File '1 (6429).jpg' has 0 faces bro
# File '1 (6432).jpg' has 0 faces bro
# File '1 (6439).jpg' has 0 faces bro
# File '1 (6446).jpg' has 0 faces bro
# File '1 (6448).jpg' has 0 faces bro
# File '1 (645).jpg' has 0 faces bro
# File '1 (6454).jpg' has 0 faces bro
# File '1 (6470).jpg' has 0 faces bro
# File '1 (648).jpg' has 0 faces bro
# File '1 (6490).jpg' has 0 faces bro
# File '1 (65).jpg' has 0 faces bro
# File '1 (6508).jpg' has 0 faces bro
# File '1 (6512).jpg' has 0 faces bro
# File '1 (6517).jpg' has 0 faces bro
# File '1 (6518).jpg' has 0 faces bro
# File '1 (6519).jpg' has 0 faces bro
# File '1 (6521).jpg' has 0 faces bro
# File '1 (6523).jpg' has 0 faces bro
# File '1 (6524).jpg' has 0 faces bro
# File '1 (6533).jpg' has 0 faces bro
# File '1 (6537).jpg' has 0 faces bro
# File '1 (6538).jpg' has 0 faces bro
# File '1 (6540).jpg' has 0 faces bro
# File '1 (6542).jpg' has 0 faces bro
# File '1 (6548).jpg' has 0 faces bro
# File '1 (6562).jpg' has 0 faces bro
# File '1 (6565).jpg' has 0 faces bro
# File '1 (6571).jpg' has 0 faces bro
# File '1 (6581).jpg' has 0 faces bro
# File '1 (659).jpg' has 0 faces bro
# File '1 (6593).jpg' has 0 faces bro
# File '1 (6596).jpg' has 0 faces bro
# File '1 (6601).jpg' has 0 faces bro
# File '1 (6602).jpg' has 0 faces bro
# File '1 (6607).jpg' has 0 faces bro
# File '1 (6610).jpg' has 0 faces bro
# File '1 (6615).jpg' has 0 faces bro
# File '1 (6619).jpg' has 0 faces bro
# File '1 (6621).jpg' has 0 faces bro
# File '1 (6632).jpg' has 0 faces bro
# File '1 (6633).jpg' has 0 faces bro
# File '1 (6639).jpg' has 0 faces bro
# File '1 (6652).jpg' has 0 faces bro
# File '1 (6656).jpg' has 0 faces bro
# File '1 (6672).jpg' has 0 faces bro
# File '1 (6682).jpg' has 0 faces bro
# File '1 (6685).jpg' has 0 faces bro
# File '1 (6698).jpg' has 0 faces bro
# File '1 (670).jpg' has 0 faces bro
# File '1 (6703).jpg' has 0 faces bro
# File '1 (6707).jpg' has 0 faces bro
# File '1 (6708).jpg' has 0 faces bro
# File '1 (6710).jpg' has 0 faces bro
# File '1 (6714).jpg' has 0 faces bro
# File '1 (6717).jpg' has 0 faces bro
# File '1 (6728).jpg' has 0 faces bro
# File '1 (673).jpg' has 0 faces bro
# File '1 (6761).jpg' has 0 faces bro
# File '1 (6762).jpg' has 0 faces bro
# File '1 (6763).jpg' has 0 faces bro
# File '1 (6766).jpg' has 0 faces bro
# File '1 (6767).jpg' has 0 faces bro
# File '1 (677).jpg' has 0 faces bro
# File '1 (6780).jpg' has 0 faces bro
# File '1 (6782).jpg' has 0 faces bro
# File '1 (6785).jpg' has 0 faces bro
# File '1 (6787).jpg' has 0 faces bro
# File '1 (6793).jpg' has 0 faces bro
# File '1 (6794).jpg' has 0 faces bro
# File '1 (6798).jpg' has 0 faces bro
# File '1 (68).jpeg' has 0 faces bro
# File '1 (6800).jpg' has 0 faces bro
# File '1 (6805).jpg' has 0 faces bro
# File '1 (6807).jpg' has 0 faces bro
# File '1 (6814).jpg' has 0 faces bro
# File '1 (682).jpg' has 0 faces bro
# File '1 (6820).jpg' has 0 faces bro
# File '1 (6822).jpg' has 0 faces bro
# File '1 (6827).jpg' has 0 faces bro
# File '1 (6831).jpg' has 0 faces bro
# File '1 (6845).jpg' has 0 faces bro
# File '1 (6852).jpg' has 0 faces bro
# File '1 (6856).jpg' has 0 faces bro
# File '1 (6861).jpg' has 0 faces bro
# File '1 (6862).jpg' has 0 faces bro
# File '1 (6863).jpg' has 0 faces bro
# File '1 (6867).jpg' has 0 faces bro
# File '1 (6872).jpg' has 0 faces bro
# File '1 (6879).jpg' has 0 faces bro
# File '1 (6880).jpg' has 0 faces bro
# File '1 (6881).jpg' has 0 faces bro
# File '1 (6894).jpg' has 0 faces bro
# File '1 (69).jpg' has 0 faces bro
# File '1 (6900).jpg' has 0 faces bro
# File '1 (6915).jpg' has 0 faces bro
# File '1 (6924).jpg' has 0 faces bro
# File '1 (6935).jpg' has 0 faces bro
# File '1 (6944).jpg' has 0 faces bro
# File '1 (6945).jpg' has 0 faces bro
# File '1 (6957).jpg' has 0 faces bro
# File '1 (6961).jpg' has 0 faces bro
# File '1 (6962).jpg' has 0 faces bro
# File '1 (6964).jpg' has 0 faces bro
# File '1 (6991).jpg' has 0 faces bro
# File '1 (704).jpg' has 0 faces bro
# File '1 (708).jpg' has 0 faces bro
# File '1 (710).jpg' has 0 faces bro
# File '1 (717).jpg' has 0 faces bro
# File '1 (72).jpg' has 0 faces bro
# File '1 (738).jpg' has 0 faces bro
# File '1 (753).jpg' has 0 faces bro
# File '1 (757).jpg' has 0 faces bro
# File '1 (759).jpg' has 0 faces bro
# File '1 (76).jpg' has 0 faces bro
# File '1 (764).jpg' has 0 faces bro
# File '1 (771).jpg' has 0 faces bro
# File '1 (772).jpg' has 0 faces bro
# File '1 (776).jpg' has 0 faces bro
# File '1 (789).jpg' has 0 faces bro
# File '1 (82).jpg' has 0 faces bro
# File '1 (823).jpg' has 0 faces bro
# File '1 (825).jpg' has 0 faces bro
# File '1 (827).jpg' has 0 faces bro
# File '1 (83).jpg' has 0 faces bro
# File '1 (851).jpg' has 0 faces bro
# File '1 (858).jpg' has 0 faces bro
# File '1 (864).jpg' has 0 faces bro
# File '1 (869).jpg' has 0 faces bro
# File '1 (879).jpg' has 0 faces bro
# File '1 (88).jpg' has 0 faces bro
# File '1 (885).jpg' has 0 faces bro
# File '1 (886).jpg' has 0 faces bro
# File '1 (887).jpg' has 0 faces bro
# File '1 (888).jpg' has 0 faces bro
# File '1 (891).jpg' has 0 faces bro
# File '1 (895).jpg' has 0 faces bro
# File '1 (913).jpg' has 0 faces bro
# File '1 (918).jpg' has 0 faces bro
# File '1 (925).jpg' has 0 faces bro
# File '1 (934).jpg' has 0 faces bro
# File '1 (941).jpg' has 0 faces bro
# File '1 (945).jpg' has 0 faces bro
# File '1 (946).jpg' has 0 faces bro
# File '1 (95).jpg' has 0 faces bro
# File '1 (950).jpg' has 0 faces bro
# File '1 (960).jpg' has 0 faces bro
# File '1 (963).jpg' has 0 faces bro
# File '1 (972).jpg' has 0 faces bro
# File '1 (981).jpg' has 0 faces bro

# %% [markdown]
# # Build the neural network

# %%
from keras_vggface.vggface import VGGFace

# Augmenting the Training Images
train_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

train_generator = train_datagen.flow_from_directory(
    'photos',
    target_size=(224,224),
    color_mode='rgb',
    batch_size=32,
    class_mode='categorical',
    shuffle=True)

# Number of classes we have
n_classes = len(train_generator.class_indices.values())

# Building the model
def generate_model():
    # Use 19 layers from original VGG-Face
    base_model = VGGFace(
        include_top=False,
        model='vgg16',
        input_shape=(224, 224, 3)
    )

    # Adding custom layers
    x = base_model.output
    x = GlobalAveragePooling2D()(x)

    x = Dense(1024, activation='relu')(x)
    x = Dense(1024, activation='relu')(x)
    x = Dense(512, activation='relu')(x)

    # final layer with softmax activation
    predictions = Dense(n_classes, activation='softmax')(x)

    model = Model(inputs = base_model.input, outputs = predictions)

    # Freeze training for the first 19 layers (keep VGG's feature extraction)
    for layer in model.layers[:19]:
        layer.trainable = False

    # Train the rest of the layers - 19 onwards
    for layer in model.layers[19:]:
        layer.trainable = True

    return model

model = generate_model()
# Out:
# Found 6471 images belonging to 4 classes.

# %%
# Saving the training labels
import pickle

class_dictionary = train_generator.class_indices
class_dictionary = {value:key for key, value in class_dictionary.items()}
print(class_dictionary)

# save the class dictionary with pickle format
face_label_filename = 'face-labels.pickle'
with open(face_label_filename, 'wb') as f: pickle.dump(class_dictionary, f)
# Out:
# {0: 'Dorime', 1: 'Kibon', 2: 'Ku', 3: 'Unknown'}

# %% [markdown]
# # K-fold cross validation

# %%
from tensorflow.keras.preprocessing import image_dataset_from_directory

# Load dataset
def load_dataset(folder):
    images = image_dataset_from_directory(
        directory=folder,
        label_mode='categorical',
        image_size=(224, 224),
        color_mode='rgb',
        shuffle=True
    )
    return images

# %%
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.losses import sparse_categorical_crossentropy
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import KFold
import numpy as np

# General definitions
loss_fn = 'categorical_crossentropy'
optimizer = 'Adam'
metrics = ['accuracy']

batch_size = 1
verbose = 1
epochs = 20

num_folds = 5

# Merge inputs and targets
inputs = load_dataset('./photos')

train_images = np.concatenate(list(inputs.map(lambda x, y:x)))
train_labels = np.concatenate(list(inputs.map(lambda x, y:y)))

# Define the K-fold Cross Validator
kfold = KFold(n_splits=num_folds, shuffle=True)
early_stopping = EarlyStopping()

# K-fold Cross Validation model evaluation
acc_per_fold = []
loss_per_fold = []
for fold_no, (train, test) in enumerate(kfold.split(train_images, train_labels)):
    # Define the model architecture then compile
    model = generate_model()
    model.compile(loss=loss_fn, optimizer=optimizer, metrics=metrics)

    print('------------------------------------------------------------------------')
    print(f'Training for fold {fold_no} ...')

    # Fit data to model
    history = model.fit(train_generator, batch_size=batch_size, verbose=verbose, epochs=epochs, callbacks=[early_stopping], validation_data=(train_images[test], train_labels[test]))

    # Generate generalization metrics
    scores = model.evaluate(train_images[test], train_labels[test], verbose=0)
    print(f'Score for fold {fold_no}: {model.metrics_names[0]} of {scores[0]}; {model.metrics_names[1]} of {scores[1]*100}%')
    acc_per_fold.append(scores[1] * 100)
    loss_per_fold.append(scores[0])

# == Provide average scores ==
print('------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(acc_per_fold)):
    print('------------------------------------------------------------------------')
    print(f'> Fold {i+1} - Loss: {loss_per_fold[i]} - Accuracy: {acc_per_fold[i]}%')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(acc_per_fold)} (+- {np.std(acc_per_fold)})')
print(f'> Loss: {np.mean(loss_per_fold)}')
print('------------------------------------------------------------------------')

# creates a HDF5 file
model.save(
    'k_fold_trained' +
    '_face_cnn_model.h5')
# Out:
# Found 6471 files belonging to 4 classes.
# ------------------------------------------------------------------------
# Training for fold 0 ...
# Epoch 1/20
# 203/203 [==============================] - 28s 135ms/step - loss: 0.0648 - accuracy: 0.9853 - val_loss: 50.7064 - val_accuracy: 0.9691
# Epoch 2/20
# 203/203 [==============================] - 26s 129ms/step - loss: 0.0155 - accuracy: 0.9947 - val_loss: 88.2797 - val_accuracy: 0.9676
# Score for fold 0: loss of 88.27967071533203; accuracy of 96.75675630569458%
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Epoch 1/20
# 203/203 [==============================] - 30s 146ms/step - loss: 0.0837 - accuracy: 0.9818 - val_loss: 41.7178 - val_accuracy: 0.9753
# Epoch 2/20
# 203/203 [==============================] - 26s 129ms/step - loss: 0.0137 - accuracy: 0.9952 - val_loss: 78.5031 - val_accuracy: 0.9768
# Score for fold 1: loss of 78.50308227539062; accuracy of 97.68160581588745%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Epoch 1/20
# 203/203 [==============================] - 27s 132ms/step - loss: 0.0634 - accuracy: 0.9844 - val_loss: 67.6702 - val_accuracy: 0.9737
# Epoch 2/20
# 203/203 [==============================] - 26s 129ms/step - loss: 0.0178 - accuracy: 0.9951 - val_loss: 77.2606 - val_accuracy: 0.9706
# Score for fold 2: loss of 77.26060485839844; accuracy of 97.06336855888367%
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Epoch 1/20
# 203/203 [==============================] - 28s 133ms/step - loss: 0.0667 - accuracy: 0.9818 - val_loss: 44.7188 - val_accuracy: 0.9784
# Epoch 2/20
# 203/203 [==============================] - 26s 129ms/step - loss: 0.0150 - accuracy: 0.9938 - val_loss: 81.7949 - val_accuracy: 0.9714
# Score for fold 3: loss of 81.79489135742188; accuracy of 97.14064598083496%
# ------------------------------------------------------------------------
# Training for fold 4 ...
# Epoch 1/20
# 203/203 [==============================] - 28s 134ms/step - loss: 0.0704 - accuracy: 0.9815 - val_loss: 68.9607 - val_accuracy: 0.9861
# Epoch 2/20
# 203/203 [==============================] - 26s 130ms/step - loss: 0.0168 - accuracy: 0.9938 - val_loss: 76.7900 - val_accuracy: 0.9799
# Score for fold 4: loss of 76.79004669189453; accuracy of 97.9907214641571%
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 88.27967071533203 - Accuracy: 96.75675630569458%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 78.50308227539062 - Accuracy: 97.68160581588745%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 77.26060485839844 - Accuracy: 97.06336855888367%
# ------------------------------------------------------------------------
# > Fold 4 - Loss: 81.79489135742188 - Accuracy: 97.14064598083496%
# ------------------------------------------------------------------------
# > Fold 5 - Loss: 76.79004669189453 - Accuracy: 97.9907214641571%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 97.32661962509155 (+- 0.44624611400388287)
# > Loss: 80.5256591796875
# ------------------------------------------------------------------------

# %%
# plotting the loss vs. epochs graph on the training and validation sets

def plot_metric(history, metric):
    train_metrics = history.history[metric]
    val_metrics = history.history['val_'+metric]
    epochs = range(1, len(train_metrics) + 1)
    plt.plot(epochs, train_metrics)
    plt.plot(epochs, val_metrics)
    plt.title('Training and validation '+ metric)
    plt.xlabel("Epochs")
    plt.ylabel(metric)
    plt.legend(["train_"+metric, 'val_'+metric])
    plt.show()

y = np.array(history.history['loss'])
y_norm = np.linalg.norm(y)
if y_norm != 0: y = y/y_norm

val_y = np.array(history.history['val_loss'])
y_norm = np.linalg.norm(val_y)
if y_norm != 0: val_y = val_y/y_norm

x = np.array([i for i in range(len(y))]) + 1

import matplotlib.pyplot as plt

plt.plot(x, y, marker='o', label="loss")
plt.plot(x, val_y, marker='o', label="validation loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.xticks(range(1, 3))
plt.title("Training loss over epochs")
plt.legend()
plt.show()

# %% [markdown]
# # Testing the Trained Model

# %%
import cv2
import os
import pickle
import numpy as np
import pickle

from PIL import Image
import matplotlib.pyplot as plt
import keras.utils as image
from keras_vggface import utils

# dimension of images
image_width = 224
image_height = 224

# load the training labels
face_label_filename = 'face-labels.pickle'
with open(face_label_filename, "rb") as f:
    class_dictionary = pickle.load(f)

class_list = [value for _, value in class_dictionary.items()]
print(class_list)
# Out:
# ['Dorime', 'Kibon', 'Ku', 'Unknown']

# %%
# Predicting the faces
facecascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

files = [os.path.join(dp, f) for dp, dn, filenames in os.walk("./facetest") for f in filenames]
subdirectories = [x[0] for x in os.walk('facetest')][1:]

fig = plt.figure(figsize=(16, 9))

none_count = 0
for i, subdirectory in enumerate(subdirectories):
    for j, file in enumerate(os.listdir(subdirectory)):
        test_image_filename = os.path.join(subdirectory, file)
        print(f"Now on file {file} of subdir {subdirectory}")
        # load the image
        imgtest = cv2.imread(test_image_filename, cv2.IMREAD_COLOR)
        if imgtest is None:
            none_count += 1
            print(f"{test_image_filename} was None ({none_count} nones)")

        image_array = np.array(imgtest, "uint8")

        # get the faces detected in the image
        faces = facecascade.detectMultiScale(imgtest, scaleFactor=1.1, minNeighbors=5)

        for (x_, y_, w, h) in faces[:1]:
            # draw the face detected
            face_detect = cv2.rectangle(imgtest, (x_, y_), (x_+w, y_+h), (255, 0, 255), 2)

            # resize the detected face to 224x224
            size = (image_width, image_height)
            roi = image_array[y_: y_ + h, x_: x_ + w]
            resized_image = cv2.resize(roi, size)

            # prepare the image for prediction
            x = image.img_to_array(resized_image)
            x = np.expand_dims(x, axis=0)
            x = utils.preprocess_input(x, version=1)

            # making prediction
            predicted_prob = model.predict(x)
            print(predicted_prob)
            
            ax = fig.add_subplot(4, 5, (i*5)+(j+1))
            ax.imshow(face_detect)
            pred_class = predicted_prob[0].argmax()
            pred_probability = predicted_prob[0][pred_class]*100
            ax.set_title("{0} - {1:.2f}%".format(class_list[pred_class], pred_probability))

plt.subplots_adjust(wspace=0.05, hspace=0.40)
plt.show()
# Out:
# Now on file photo_2023-06-20_23-58-34.jpg of subdir facetest\Dorime
# 1/1 [==============================] - 0s 20ms/step
# [[1. 0. 0. 0.]]
# Now on file photo_2023-06-20_23-58-38.jpg of subdir facetest\Dorime
# 1/1 [==============================] - 0s 17ms/step
# [[1. 0. 0. 0.]]
# Now on file photo_2023-06-23_20-51-58.jpg of subdir facetest\Dorime
# 1/1 [==============================] - 0s 15ms/step
# [[1. 0. 0. 0.]]
# Now on file photo_2023-06-23_20-54-17.jpg of subdir facetest\Dorime
# 1/1 [==============================] - 0s 17ms/step
# [[1. 0. 0. 0.]]
# Now on file photo_2023-06-23_21-40-33.jpg of subdir facetest\Dorime
# 1/1 [==============================] - 0s 16ms/step
# [[1. 0. 0. 0.]]
# Now on file 20230623_174237.jpg of subdir facetest\Kibon
# 1/1 [==============================] - 0s 17ms/step
# [[0.0000000e+00 9.9999952e-01 4.5743752e-07 0.0000000e+00]]
# Now on file 20230623_174243.jpg of subdir facetest\Kibon
# 1/1 [==============================] - 0s 17ms/step
# [[0.000000e+00 1.000000e+00 9.154334e-12 0.000000e+00]]
# Now on file 20230623_174258.jpg of subdir facetest\Kibon
# 1/1 [==============================] - 0s 18ms/step
# [[0.0000000e+00 1.0000000e+00 6.3833155e-14 0.0000000e+00]]
# Now on file 20230623_174322.jpg of subdir facetest\Kibon
# 1/1 [==============================] - 0s 16ms/step
# [[0. 0. 0. 1.]]
# Now on file 20230623_174342.jpg of subdir facetest\Kibon
# 1/1 [==============================] - 0s 17ms/step
# [[0.0000000e+00 1.0000000e+00 2.8411405e-33 1.3142435e-38]]
# Now on file 20230623_174027.jpg of subdir facetest\Ku
# 1/1 [==============================] - 0s 16ms/step
# [[0. 0. 1. 0.]]
# Now on file 20230623_174128.jpg of subdir facetest\Ku
# 1/1 [==============================] - 0s 20ms/step
# [[0. 0. 1. 0.]]
# Now on file photo_1_2023-06-23_21-42-08.jpg of subdir facetest\Ku
# 1/1 [==============================] - 0s 15ms/step
# [[0. 0. 1. 0.]]
# Now on file photo_2_2023-06-23_21-42-08.jpg of subdir facetest\Ku
# 1/1 [==============================] - 0s 16ms/step
# [[0. 0. 1. 0.]]
# Now on file photo_3_2023-06-23_21-42-08.jpg of subdir facetest\Ku
# 1/1 [==============================] - 0s 17ms/step
# [[0. 0. 0. 1.]]
# Now on file 20230311_110316.jpg of subdir facetest\Unknown
# 1/1 [==============================] - 0s 15ms/step
# [[0. 0. 0. 1.]]
# Now on file 20230623_174910.jpg of subdir facetest\Unknown
# 1/1 [==============================] - 0s 17ms/step
# [[0. 0. 0. 1.]]
# Now on file IMG_20230623_175748_072.jpg of subdir facetest\Unknown
# 1/1 [==============================] - 0s 16ms/step
# [[0. 0. 0. 1.]]
# Now on file IMG_20230623_175757_127.jpg of subdir facetest\Unknown
# 1/1 [==============================] - 0s 17ms/step
# [[0. 0. 0. 1.]]
# Now on file IMG_20230623_175815_927.jpg of subdir facetest\Unknown
# 1/1 [==============================] - 0s 15ms/step
# [[0. 0. 0. 1.]]
